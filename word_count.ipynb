# %% [markdown]
# # Word Count
# Counts words using Count Vectorizer / utilizing word_count module
#
# **Reference**
# * [Coalition Treaty SPIEGEL](https://www.spiegel.de/politik/koalitionsvertrag-der-ampel-parteien-im-wortlaut-darauf-haben-sich-spd-gruene-und-fdp-geeinigt-a-3e25c4da-088a-4971-8a4d-4797a4ecf089)
#
# * German Stop Words
#     * https://countwordsfree.com/stopwords/german
#     * https://github.com/stopwords-iso/stopwords-de

# %%
from machine_learning import wordcount_analysis as wa
fp_stoplist = r"<path to stoplist>"
f = r"C:\<path to txt file>.txt"
key_len = 6
df = wa.get_keywordcluster_df(f,fp_stoplist=fp_stoplist,key_len=key_len)
df.head(20)
#df.loc["bundes"]["keywords"].split(", ")
# Out:
# Reading stoplist from C:\05_TRANSIENT\Henrik\_UMO\stopwords-de.txt
# Using stoplist with 620 elements
# Number of Lines in C:\05_TRANSIENT\Henrik\_UMO\koalitionsvertrag.txt: 2327
# Number of Keywords: 9966
# Number of Clustered Keywords: 4387
#         count  sum                                           keywords
# stärke      5  288  stärke(6), stärken(237), stärker(38), stärkere...
# bundes    102  287  bundes(39), bundesagentur(1), bundesakademie(1...
# unters     21  245  untersagen(2), unterschiede(5), unterschiedlic...
# deutsc     12  244  deutsch(7), deutsche(31), deutschem(1), deutsc...
# digita     22  225  digital(18), digitalbudget(1), digitalcheck(1)...
# sicher     38  218  sicher(17), sichere(6), sicheren(1), sicherer(...
# förder     36  211  förder(3), förderauftrag(1), förderbank(1), fö...
# arbeit     61  210  arbeit(52), arbeiten(16), arbeitenden(1), arbe...
# europä      6  179  europäisch(6), europäische(49), europäischem(2...
# ...
